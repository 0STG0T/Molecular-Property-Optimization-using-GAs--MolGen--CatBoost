# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'OC[C@@HC@@HC@HC@@HC(O)=O' for input: 'OC[C@@HC@@HC@HC@@HC(O)=O'
# [04:27:54] SMILES Parse Error: syntax error while parsing: OC(=O)C@@HC@@HC(O)=O
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'OC(=O)C@@HC@@HC(O)=O' for input: 'OC(=O)C@@HC@@HC(O)=O'
# [04:27:54] SMILES Parse Error: syntax error while parsing: CC(C)(S)C@@HC(O)=O
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'CC(C)(S)C@@HC(O)=O' for input: 'CC(C)(S)C@@HC(O)=O'
# [04:27:54] SMILES Parse Error: syntax error while parsing: H+].[Cl-].C[C@@HNC(=O)C1)N1CC(=O)NC(=O)C1
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'H+].[Cl-].C[C@@HNC(=O)C1)N1CC(=O)NC(=O)C1' for input: 'H+].[Cl-].C[C@@HNC(=O)C1)N1CC(=O)NC(=O)C1'
# [04:27:54] SMILES Parse Error: syntax error while parsing: O=C(O)CN1CCN(CC(=O)O)CCN(C[C+O)CCN(CC(=O)O)CC1
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'O=C(O)CN1CCN(CC(=O)O)CCN(C[C+O)CCN(CC(=O)O)CC1' for input: 'O=C(O)CN1CCN(CC(=O)O)CCN(C[C+O)CCN(CC(=O)O)CC1'
# [04:27:54] SMILES Parse Error: syntax error while parsing: O=C(O)CN1CCH]N(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'O=C(O)CN1CCH]N(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1' for input: 'O=C(O)CN1CCH]N(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1'
# [04:27:54] SMILES Parse Error: syntax error while parsing: O=C(O)CN1CCN(CCCO)CCN(CC(=O)O)CCN(C[C+O)CC1
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'O=C(O)CN1CCN(CCCO)CCN(CC(=O)O)CCN(C[C+O)CC1' for input: 'O=C(O)CN1CCN(CCCO)CCN(CC(=O)O)CCN(C[C+O)CC1'
# [04:27:54] SMILES Parse Error: syntax error while parsing: CCCC@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'CCCC@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O' for input: 'CCCC@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O'
# [04:27:54] SMILES Parse Error: syntax error while parsing: CCC[C@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O
# [04:27:54] SMILES Parse Error: Failed parsing SMILES 'CCC[C@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O' for input: 'CCC[C@@HO)CC(=O)O)N(CC(=O)O)CC(=O)O'

# %%
from collections import Counter
from rdkit.Contrib.SA_Score import sascorer

data = pd.read_csv("logK.csv")

def check_molecule(smiles):
    # Разрешенные элементы и элементы для подсчета атомов
    allowed_elements = {'C', 'H', 'O', 'N', 'P', 'S'}
    count_elements = {'O', 'N', 'P', 'S'}

    # Счетчик элементов в молекуле
    elements_counter = Counter()
    temp_element = '' # Временная переменная для хранения элементов более одного символа

    for char in smiles:
        if char.isalpha():
            # Проверяем, является ли элемент двухбуквенным (например, Cl) - не применимо к данным элементам, но полезно для общности
            if temp_element:
                # Предыдущий элемент был начат, завершаем его
                elements_counter[temp_element] += 1
                temp_element = ''
            if char.isupper():
                # Начало нового элемента
                elements_counter[char] += 1
            else:
                # Продолжение текущего элемента
                temp_element += char
        elif temp_element:
            # Если был накоплен временный элемент, добавляем его в счетчик
            elements_counter[temp_element] += 1
            temp_element = '' # Сброс временного элемента

    # Проверяем, входит ли последний элемент в счетчик, если цикл завершился на букве
    if temp_element:
        elements_counter[temp_element] += 1

    # Проверка условий
    # 1. Все элементы в молекуле должны быть из разрешенного списка
    if not all(element in allowed_elements for element in elements_counter):
        print('# 1. Все элементы в молекуле должны быть из разрешенного списка')
        return False

    # 2. Молекула должна включать не менее трех разных элементов из списка
    if sum(element in allowed_elements for element in elements_counter) < 3:
        print('# 2. Молекула должна включать не менее трех разных элементов из списка')
        return False

    # 3. Суммарно не более 12 атомов элементов O, N, P, S
    if sum(count for element, count in elements_counter.items() if element in count_elements) > 12:
        print('# 3. Суммарно не более 12 атомов элементов O, N, P, S')
        return False
    
    if smiles in data["smiles"].tolist():
      return True

    weight = ExactMolWt(Chem.MolFromSmiles(smiles))
    if weight > 500: 
        print('Вес: ', weight)
        return False

    if sascorer.calculateScore(Chem.MolFromSmiles(smiles))>5: 
        print('Sas > 5', sascorer.calculateScore(Chem.MolFromSmiles(smiles)))
        return False
        

    return True

# Тестирование функции на нескольких молекулах из датасета

# %%
sub = pd.DataFrame({"smiles": chelates})

sub = sub.rename(columns={0:"smiles"})

sub.shape
# Out:
# (114, 1)

# %%
checked = [check_molecule(smiles) for smiles in sub["smiles"]]

sub = sub.iloc[checked]

can_smiles = [Chem.MolToSmiles(Chem.MolFromSmiles(m), isomericSmiles=True, canonical=True) for m in sub.smiles.tolist()]

can_smiles = list(set(can_smiles))
sub_can = pd.DataFrame({"smiles": can_smiles})

sub_can.shape
# Out:
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 2. Молекула должна включать не менее трех разных элементов из списка
# # 2. Молекула должна включать не менее трех разных элементов из списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 2. Молекула должна включать не менее трех разных элементов из списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# (79, 1)

# %%
model = CatLgKPredictor('./mymodel')
sub_can["lgk"] = model.predict_lgK(pd.DataFrame({'smiles': sub_can["smiles"].values}))

sub_can.reset_index(drop=True, inplace=True)

sub_can.shape
# Out:
# (79, 2)

# %%
from rdkit import DataStructs

def return_unsimilar(sub: pd.DataFrame):
    sub = sub.copy()
    
    ms = [Chem.MolFromSmiles(sm) for sm in sub['smiles']]
    fpgen = AllChem.GetRDKitFPGenerator()
    fps = [fpgen.GetFingerprint(x) for x in ms]
    sim = 0
    for i in range(len(fps)):
        for j in range(i+1, len(fps)):
            try:
                if DataStructs.TanimotoSimilarity(fps[i], fps[j]) > 0.5:
                    if sub["lgk"][i]>=sub["lgk"][j] and sub["lgk"][j]<sub['lgk'].mean():
                        sub.drop(labels=[j], inplace=True)
                    elif sub["lgk"][i]<sub["lgk"][j] and sub["lgk"][i]<sub['lgk'].mean():
                        sub.drop(labels=[i], inplace=True)
            except KeyError:
                pass
    return sub

# %%
sub_can_sim = return_unsimilar(sub_can)
sub_can_sim.head()
# Out:
#                                             smiles        lgk
# 0        CCCC(CN(CC(=O)O)CC(=O)O)N(CC(=O)O)CC(=O)O  20.786398
# 1       O=C(O)CN(CC(=O)O)C1CCCCC1N(CC(=O)O)CC(=O)O  21.335123
# 2  O=C(O)COCN1CCN(CCCO)CCN(CC(=O)O)CCN(CC(=O)O)CC1  19.677119
# 3                                    CCN(CC)C(=S)S   5.578944
# 4   O=C(O)CN1CCN(CC#CO)CCN(CC(=O)O)CCN(CC(=O)O)CC1  21.231114

# %%
sub_can_sim.sort_values(by="lgk", ascending=False)["lgk"][:100].mean()
# Out:
# 19.445796805377306

# %%
data.sort_values(by="lgK", ascending=False).head()
# Out:
#       id                                             smiles    lgK
# 191  193  O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n...  29.30
# 149  151   O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1  28.60
# 150  152  O=C(O)CCP(=O)(O)CN1CCN(C(=O)O)CCN(C(=O)O)CCN(C...  25.50
# 136  137  O=P(O)(O)CN1CCN(CP(=O)(O)O)CCN(CP(=O)(O)O)CCN(...  24.78
# 71    72  O=C(O)CN1CCN(CC(=O)O)CCN(CC(=O)O)CCN(CC(=O)O)C...  24.26

# %%
from pred import CatLgKPredictor
model = CatLgKPredictor("./mymodel")

# %%
da = pd.read_csv("./logK.csv")

# %%
da = data.sort_values(by="lgK", ascending=False).loc[data["lgK"]>21.5]
ind = []
for i in da["smiles"].tolist():
    try:
        predicted_log_k = model.predict_lgK(pd.DataFrame({"smiles": [sf.decoder(sf.encoder(i))]}))
        ind.append(sf.encoder(i))
    except Exception:
        pass

initial_population = ind

#ind += chelates

best_sub = pd.read_csv("./BBBEST_SUB.csv", header=None)
best_sub['lgk'] = model.predict_lgK(best_sub.rename(columns={0:"smiles"}))
best_sub = best_sub.sort_values(by="lgk", ascending=False).loc[best_sub["lgk"]>21.5]
ind_bs = []

for i in best_sub[0].tolist():
    try:
        predicted_log_k = model.predict_lgK(pd.DataFrame({"smiles": [sf.decoder(sf.encoder(i))]}))
        ind_bs.append(sf.encoder(i))
    except Exception:
        pass
    
ind+=ind_bs

ind += ['O=C(O)CN(CC1)CCN(CC(=O)O)CCN(CC(=O)O)CCN1CC(=O)O']

# %%
len(ind)
# Out:
# 26

# %%
chelates = ['CC(=O)NC1=C2SSC=C2NC1=O', 'N[C@@H](CCN[C@@H](CCN1CC[C@H]1C(O)=O)C(O)=O)C(O)=O', 'OC(CS)C(O)CS','[C@@]1(OC=2C=C(O)C=C(O)C2C[C@H]1O)([H])C3=CC(=O)C(=C4C(=C3)C([C@]5(OC=6C=C(O)C=C(O)C6C[C@H]5O)[H])=CC(O)=C4O)O' 'OC(=O)CC(O)(CC(O)=O)C(O)=O', 'OC[C@@H](O)[C@@H](O)[C@H](O)[C@@H](O)C(O)=O', 'OC(=O)[C@@H](S)[C@@H](S)C(O)=O', 'Oc1c(I)cc(Cl)c2cccnc12', 'O=C(O)CN(CC1)CCN(CC(=O)O)CCN(CC(=O)O)CCN1CC(=O)O', 'OCC(S)CS', 'C1CSCCSCCS1', 'CC(C)(S)[C@@H](N)C(O)=O', 'C1=CN=C(C=C1)C1=CC=CC=N1', 'CCCCC(O)(Cn1cncn1)c1ccc(Cl)cc1Cl', '[H+].[Cl-].C[C@@H](CN1CC(=O)NC(=O)C1)N1CC(=O)NC(=O)C1', 'C(=S)(S)N(CC)CC', 'Cc1cc(-c2ccc(cc2)S(O)(=O)=O)c2ccc3c(cc(C)nc3c2n1)-c1ccc(cc1)S(O)(=O)=O', 'OC(=O)CN(CCOCCOCCN(CC(O)=O)CC(O)=O)CC(O)=O', 'OC(=O)CN(CCN(CC(O)=O)CC(O)=O)CC(O)=O', 'CC(O)(P(O)(O)=O)P(O)(O)=O', 'OC(=O)CNCC(O)=O', 'OP(O)(=O)CP(O)(O)=O', 'N1=C(C=CC2=CC=C3C=CC(=NC3=C12)C)C', 'OC(=O)CN1CCCN(CCN(CCCN(CC1)CC(O)=O)CC(O)=O)CC(O)=O', 'CN1C(=O)C(NC(C)=O)=C2SSC=C12', 'CCCCCCCc1cc(O)c2ccccc2n1']

# %%
initial_population[0]
# Out:
# '[O][=P][Branch1][C][O][Branch1][C][O][C][N][Branch2][Ring2][Ring2][C][C][=C][C][=C][C][Branch2][Ring1][#Branch1][C][N][Branch1][#Branch2][C][P][=Branch1][C][=O][Branch1][C][O][O][C][P][=Branch1][C][=O][Branch1][C][O][O][=N][Ring2][Ring1][C][C][P][=Branch1][C][=O][Branch1][C][O][O]'

# %%
from concurrent.futures import ThreadPoolExecutor
from rdkit.Chem.Descriptors import MolWt

valid_fragments = ['[O]', '[N]', '[C]', '[=O]', '[=N]', '[S]']

def count_onps_atoms(mol):
    """Count the total number of O, N, P, and S atoms in a molecule."""
    atom_counts = {symbol: 0 for symbol in ['O', 'N', 'P', 'S']}
    for atom in mol.GetAtoms():
        symbol = atom.GetSymbol()
        if symbol in atom_counts:
            atom_counts[symbol] += 1
    return sum(atom_counts.values())

def evaluate_fitness(selfie, model):
    try:
        smi = sf.decoder(selfie)
        mol = Chem.MolFromSmiles(smi)
        if mol is None:
            return -1 
    
        
        predicted_log_k = model.predict_lgK(pd.DataFrame({"smiles": [smi]}))
        if predicted_log_k[0] <= 22:
            return -10 
        
        fitness_score = predicted_log_k
    except Exception:
        return -1
    return fitness_score


def parallel_evaluate_fitness(population, model):
    with ThreadPoolExecutor() as executor:
        scores = list(executor.map(evaluate_fitness, population, [model] * len(population)))
    return scores

def tournament_selection(population, scores, k=3):
    # Ensure k does not exceed the size of the population
    k = min(k, len(population))
    
    if len(population) == 0:
        raise ValueError("Population is empty.")
    
    selection_idxs = random.sample(range(len(population)), k)
    selected_scores = [scores[idx] for idx in selection_idxs]
    winner_idx = selection_idxs[selected_scores.index(max(selected_scores))]
    return population[winner_idx]

import selfies as sf
import random

def split_selfie_into_fragments(selfie):
    """Split a SELFIES string into a list of fragments (individual symbols)."""
    return sf.split_selfies(selfie)

def combine_fragments_into_selfie(fragments):
    """Combine a list of SELFIES fragments into a single SELFIES string."""
    return ''.join(fragments)

def find_common_fragments(parent1, parent2):
    """Find common fragments between two SELFIES strings."""
    fragments1 = set(split_selfie_into_fragments(parent1))
    fragments2 = set(split_selfie_into_fragments(parent2))
    common = fragments1.intersection(fragments2)
    return list(common) if common else None

def crossover(parent1, parent2):
    common_fragments = find_common_fragments(parent1, parent2)
    if not common_fragments:
        return parent1, parent2
    fragment_to_swap = random.choice(common_fragments)
    index1 = parent1.find(fragment_to_swap)
    index2 = parent2.find(fragment_to_swap)
    if index1 == -1 or index2 == -1:
        return parent1, parent2
    new_offspring1 = parent1[:index1] + parent2[index2:]
    new_offspring2 = parent2[:index2] + parent1[index1:]
    return new_offspring1, new_offspring2

def find_common_fragments(parent1, parent2):
    """Identify common SELFIES fragments between two parent molecules."""
    fragments1 = set(sf.split_selfies(parent1))
    fragments2 = set(sf.split_selfies(parent2))
    return list(fragments1.intersection(fragments2))


def crossover_enhanced(parent1, parent2):
    fragments1 = list(sf.split_selfies(parent1))
    fragments2 = list(sf.split_selfies(parent2))
    common_fragments = set(fragments1) & set(fragments2)

    if not common_fragments:
        return parent1, parent2 

  
    to_swap = random.sample(list(common_fragments), min(len(common_fragments), 2))  
    offspring1, offspring2 = fragments1[:], fragments2[:]  

    for fragment in to_swap:
        idx1, idx2 = offspring1.index(fragment), offspring2.index(fragment)
        offspring1[idx1], offspring2[idx2] = offspring2[idx2], offspring1[idx1] 
    
    new_offspring1 = ''.join(offspring1)
    new_offspring2 = ''.join(offspring2)
    
    return new_offspring1, new_offspring2

def mutate(selfie, mutation_rate=0.1):
    if random.random() > mutation_rate:
        return selfie  

    fragments = list(sf.split_selfies(selfie))  
    if not fragments:
        return selfie 

    mutation_index = random.randint(0, len(fragments) - 1)

    new_fragment = random.choice(valid_fragments)
    
    fragments[mutation_index] = new_fragment
    mutated_selfie = ''.join(fragments)  
    
    smi = sf.decoder(mutated_selfie) 
    mol = Chem.MolFromSmiles(smi)

    return mutated_selfie

def run_ga(population, generations=40):
    for generation in range(generations):
        scores = parallel_evaluate_fitness(population, model)
        valid_indices = [i for i, score in enumerate(scores) if score > -1]
        valid_population = [population[i] for i in valid_indices]
        valid_scores = [scores[i] for i in valid_indices]
        
        new_population = []
        while len(new_population) < len(valid_population):
            parent1 = tournament_selection(valid_population, valid_scores)
            parent2 = tournament_selection(valid_population, valid_scores)
            offspring1, offspring2 = crossover_enhanced(parent1, parent2)
            offspring1 = mutate(offspring1)
            offspring2 = mutate(offspring2)
            new_population.extend([offspring1, offspring2])
        population = new_population[:len(valid_population)]  
    return population

run_ga(initial_population, 40)
# Out:
# ['[O][=C][Branch1][C][O][N][C][C][N][Branch1][#Branch2][C][P][=Branch1][C][=O][Branch1][C][O][O][C][C][N][Branch1][=Branch1][C][=Branch1][C][=O][O][C][C][N][Branch1][=Branch1][C][=Branch1][C][=O][O][C][C][Ring2][Ring1][#Branch1]']

# %%
len(ind)
# Out:
# 26

# %%
initial_population = ind

len(initial_population)
# Out:
# 26

# %%
subs = []
subs_len = 0
while len(subs) <= 100:
    final_population = run_ga(initial_population, generations=10)
    fin_pop = [sf.decoder(i) for i in final_population]
    fin_pop = list(set(fin_pop))
    
    can_fin_pop = [Chem.MolToSmiles(Chem.MolFromSmiles(m), isomericSmiles=True, canonical=True) for m in fin_pop]
    can_fin_pop = list(set(can_fin_pop))
    
    subs += can_fin_pop
    
    subs = list(set(subs))
    
    # logging
    if subs_len != len(subs):
        print(len(subs))
        print(subs)
        
    subs_len = len(subs)
    
    pppps = model.predict_lgK(pd.DataFrame({'smiles': subs}))
    
    
    for l in range(len(pppps)):
        if pppps[l] > 22:
            initial_population.append(subs[l])
    
    

subs
# Out:
# 1
# ['O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O']
# 2
# ['O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1']
# Object info sizes: 1 1234
# 3
# ['O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1']
# 4
# ['O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O']
# 5
# ['O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1']
# Object info sizes: 1 1234
# 6
# ['O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# 7
# ['O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# 8
# ['O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# 9
# ['O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# 10
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# Object info sizes: 1 1234
# 11
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# Object info sizes: 1 1234
# 12
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O']
# Object info sizes: 1 1234
# 13
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O']
# Object info sizes: 1 1234
# 14
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'NC(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O']
# Object info sizes: 1 1234
# Object info sizes: 1 1234
# Object info sizes: 1 1234
# Object info sizes: 1 1234
# 15
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'NC(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CS(O)(O)O)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O']
# 16
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'NC(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CS(O)(O)O)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O']
# 17
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'NC(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CS(O)(O)O)n1)CP(=O)(O)O', 'NN=C(C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O)CN(CP(=O)(O)O)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O']
# 18
# ['O=P(O)(O)CN(CC1=CC=CS(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)O', 'NC(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=C(O)CCP(=O)(O)CN1CCN(C(=O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CS(O)(O)O)n1)CP(=O)(O)O', 'NN=C(C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O)CN(CP(=O)(O)O)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CON(C(=O)O)CCN(C(=O)O)CC1', 'CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)P(=O)(O)OCP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CSN(C(=O)O)CCN(C(=O)O)CC1', 'NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=PSCOCOCN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=NCP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)OP(=O)(O)O)n1)CP(=O)(O)O', 'CP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n1)CP(=O)(O)O', 'O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1', 'O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)SP(=O)(O)O)n1)CP(=O)(O)O', 'O=P(O)(O)CN(CC1=COCC(CN(CP(=O)(O)O)CP(=O)(O)O)=N1)CP(=O)(O)
(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n1)CP(=O)(O)O', 'NN=C(C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O)CN(CP(=O)(O)O)CP(=O ...
# Object info sizes: 1 1234
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 4
#       2 subs_len = 0
#       3 while len(subs) <= 100:
# ----> 4     final_population = run_ga(initial_population, generations=10)
#       5     fin_pop = [sf.decoder(i) for i in final_population]
#       6     fin_pop = list(set(fin_pop))
#
# Cell In[17], line 144, in run_ga(population, generations)
#     142 def run_ga(population, generations=40):
#     143     for generation in range(generations):
# --> 144         scores = parallel_evaluate_fitness(population, model)
#     145         # Ensure only valid scores are selected for breeding
#     146         valid_indices = [i for i, score in enumerate(scores) if score > -1]
#
# Cell In[17], line 42, in parallel_evaluate_fitness(population, model)
#      40 def parallel_evaluate_fitness(population, model):
#      41     with ThreadPoolExecutor() as executor:
# ---> 42         scores = list(executor.map(evaluate_fitness, population, [model] * len(population)))
#      43     return scores
#
# File ~/miniconda3/envs/torch/lib/python3.11/concurrent/futures/_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File ~/miniconda3/envs/torch/lib/python3.11/concurrent/futures/_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File ~/miniconda3/envs/torch/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/torch/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     325 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326     if timeout is None:
# --> 327         waiter.acquire()
#     328         gotit = True
#     329     else:
#
# KeyboardInterrupt:

# %%
valid_smiles = []

subs1 = subs#['O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1']
# valid checking
for sm in subs1:
    if check_molecule(sm):
        valid_smiles.append(sm)
    else:
        #print('Failed check')
        pass
# Out:
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 1. Все элементы в молекуле должны быть из разрешенного списка
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S
# # 3. Суммарно не более 12 атомов элементов O, N, P, S

# %%
valid_smiles
# Out:
# ['O=C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O',
#  'N=C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O',
#  'O=CP(=O)(O)O',
#  'O=CN(CP(=O)(O)O)CP(=O)(O)O',
#  'O=CN(CCNC(=O)O)CP=O',
#  'O=NCP(=O)(O)O',
#  'N=NCP(=O)(O)O',
#  'CN(C=O)CCN(CCNCP(=O)(O)O)C(=O)O',
#  'N=C(C=CC=CCN(CP(=O)(O)O)CP(=O)(O)O)CN=O']

# %%
test = subs1

test_preds = model.predict_lgK(pd.DataFrame({'smiles': test}))
p, predds = [], []
for s in range(len(test)):
    if test_preds[s] > 21:
        p.append(test[s])
        predds.append(test_preds[s])

np.mean(predds), max(predds), min(predds)
# Out:
# (23.409447369858245, 29.016022672675394, 21.09478121151339)

# %%
len(predds)
# Out:
# 41

# %%
generated_df = pd.DataFrame({'smiles': p, 'lgK': predds})
generated_df.head()
# Out:
#                                               smiles        lgK
# 0  O=C(O)CCP(=O)(O)CN1CCN(C(=O)O)CCN(C(=O)O)CCN(C...  25.385081
# 1   C=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1  23.630224
# 2  O=P(O)(O)CN(Cc1cccc(CNCOP(=O)(O)CP(=O)(O)O)n1)...  23.010825
# 3   O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)OCN(C(=O)O)CC1  21.094781
# 4  NP(=O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n...  23.649615

# %%
generated_df.sort_values(by='lgK', ascending=False).to_csv(f'./generated/invalid_enhanced_c_{generated_df["lgK"].mean()}.csv', index=False)

# %%
generated_df = pd.read_csv(f'./generated/invalid_enhanced_c.csv')

generated_df
# Out:
#                                               smiles        lgK
# 0  O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)O)n...  29.016023
# 1   O=C(O)N1CCN(CP(=O)(O)O)CCN(C(=O)O)CCN(C(=O)O)CC1  28.399766
# 2  O=P(O)(O)CN(Cc1cccc(CN(CP(=O)(O)O)CP(=O)(O)S)n...  22.115085

# %%
tt_smiles = generated_df['smiles']
for sm in tt_smiles:
    display(Chem.MolFromSmiles(sm))
